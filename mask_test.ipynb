# %%
from app.utills.texture_utill import extract_mesh,create_texture_mask

# %%
# 예시 사용
mesh_path = "app/database/glb_files/1_catMango.glb"
mesh_data = extract_mesh(mesh_path)

# %%
uv_mask = create_texture_mask(mesh_data)  # 해상도 512x512의 UV 마스크 생성

# %%
uv_mask.show()
# Out:
# <PIL.Image.Image image mode=L size=512x512>
